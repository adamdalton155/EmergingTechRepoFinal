# %% [markdown]
# <font color=blue><h1>JupyterLite</h1>

# %% [markdown]
# ![Jupyter.png](attachment:Jupyter.png)

# %% [markdown]
# <font color=blue><h3>Project Jupyter's History</h3>
#
# JupyterLite isnt the first iteration of Project Jupyter so it makes sense to start where Jupyter started. Back in 2015, Project Jupyter was started with the goal to make an open source software for interactive computing across many programming languages. Its a branch of IPython in 2014 by Fernando Pérez and Brian Granger and the name Jupyter comes from the three main languages it supports, that being Julia, Python and R. By 2015, more than 200,000 notebooks were available on GitHub and by January 2021, nearly 10 million notebooks were available. In 2021, Nature named Project Jupyter as one of the projects that transformed computer sciecnce
#
# There have been four iterations of Project Jupyter so far, that being Jupyter Notebook, JupyterHub, JupyterLab and the latest JupyterLite. Since its development, many companies have adopted Jupyter, for example Google Colaboratory and Microsoft Azure Notebook to be used as a front end interface for cloud based users. Even Visual Studio Code supports local development of Jupyter notebooks. Jupyter Notebook is the first iteration was designed to be light weight and easy to use. It uses an ordered cell system of inputs and outputs which can either contain code or markdown language and underneath all of this is JSON (JavaScript Object Notation). Each file usually ends with the extension .ipynb. What makes Jupyter a pretty fast application is the fact that the user can choose which packages (e.g. numpy) they would like to import rather than having to load countless pre-installed packages and will run even faster if some of the statements have already been run as they may be strored in memory.

# %% [markdown]
# <font color=blue><h3>From Jupyter Notebook to Jupyter Lab</h3>
#
# In early 2018, Version 1.0, the first stable release of Jupyter Lab released, the successor to Jupyter Notebook. The release of Lab was intended to make various improvements while keeping the lightweight, easy to use style of Notebook. I've listed some of the smaller improvements that Lab made below
#     <ul>
#         <li>Flexible Layout - The ability to customise the workspace. This includes drag and drop features, resize tabs and a collapsible sidebar that has the most used files easy to access.</li>
#         <li>Reorganise cells - In Notebook, you had to add in cells either above or below by using 'A' or 'B' or by using the toolbar at the top. In Lab, you can drag and drop cells. Much easier!</li>
#         <li>Switch to classic view - Some people are just going to prefer the old layout and luckily enough, there is a setting for the user to achieve this.</li>
#         <li>Native support for Images, CSV, JSON, Markdown, PDF, Vega, Vega-Lite, etc. </li>
#     </ul>
#
# To us the biggest improvement in our opinion that Lab made over Notebook is the addition of terminal support. You can run Notebook through the terminal on the users machine and from there you can install packages but having that built into Lab greatly increases workflow. On this terminal, anything can be run including vim or emacs. Something else that we found interesting about the terminals on Lab is that the terminal actually runs where the Jupyter server itself is running.

# %% [markdown]
# <font color=blue><h3>JupyterLab and its short history</h3>
#
# And now we come to the latest iteration of Project Jupyter, JupyterLab. Running entirely in the browser, and built from scratch while using components of JupyterLab and extensions, its being developed with the purpose of being lightweight and easy to access with a few clicks and all without having to install anything on the users machine. Even though JupyterLite is quite a bit away from a fully stable 1.0 release (0.1.0 beta version at the time of writing) its already benefitting from new features, accessibility fixes, and upkeep improvements because thats it's built using the knowledge the developers have learned from developing JupyterLab. I have included two images below of the user interface just to show how similar Lite is to Lab.
#
# JupyterLite ships natively with Pyolite, a Python kernel. The benefit of this for JupyterLab is now IPython is running in the browser, as so, features Code Completion (a feature we felt was missing while working on Jupyter Notebook), a nicer display for coding with and Interactive widgets. Also supported in JupyterLite is JavaScript and p5. Because of the purpose of Project Jupyter being designed mainly towards data science, having the ability to use JavaScript and p5 to code animations is a huge feature, helping data scientists to visualise their work in different ways. Like Pyolite, JavaScript and p5's kernels are supported but interestingly as an iFrame.
#
# Deploying JupyterLite is actually quite simple. Its a static site that is served from a cacheable HTTP server, which in turn makes it so that notebooks from JupyterLite can be deployed from outside sources such as GitHub Pages, Binder and Vercel. Also, like JupyterNotebook, there is now a terminal command for launching JupyterLite. The command being 'jupyterlite'.
#
# It is not perfect though. As mentioned above, JupyterLite is still in beta and a very early version at that. This does mean issues do occur. A quick google search and you can find Github repositories and discussions about packages working one minute and the next not. The cacheable nature of the project means that by accident, data loss can occur if say for example, the developers of your browser releases an update, that ends up clearing cache and as a result, work is deleted. On the other side of this, what if the user decides to clear their cache themselves in an attempt to fix an issue with the performance of their internet browser, not realising what would happen to their work. If a user worries about this situation occuring, maybe they should use JupyterLab. On Jupyter's blog, they did mention that eventually JupyterLab will completely replace JupyterNotebook so we believe it comes down to knowing what technology is appropriate for the users needs.

# %% [markdown]
# ![liteyayout.png](attachment:liteyayout.png)

# %% [markdown]
# ![lab%20layout.png](attachment:lab%20layout.png)

# %% [markdown]
# <font color=blue><h3>Some great packages that you can import</h3>
#
# As mentioned earlier, to keep the lightweight design of Lab/Notebook/Lite, the packages have to be imported rather than having them preinstalled which just bloats the application. I wanted to share some packages and a short coding example to demonstrate what they can do. These are some packages that I feel are useful that I came across during my research and some coding examples for each package except Jupyter Themes where I have included images showing the different themes.
#     <ol>
#         <li>Numpy - The primary tool for scientific computations, which I might add was initally the main purpose of Jupyter Notebook</li>
#         <li>Pandas - Used to work with tabular, time series, or matrix data.</li>
#         <li>Matplotlib - The most common data exploration and visualization library, used to create basic graphs</li>
#         <li>Seaborn - High-level interface for drawing attractive statistical graphics</li>
#         <li>Pillow - Open and save images in various formats, create thumbnails and add image filters.</li>
#         <li>Jupyter Themes - Light Mode can be ugly, and Dark Mode is often just better. But different colour themes are included in this package.</li>
#     </ol>

# %% [markdown]
# <font color=blue><h3>Examples of the packages capabilities</h3>

# %%
#Numpy Example

import numpy as np
#Create an array 'a' of numbers that are mixed up
a = np.array([3,1,7,4,7])
#Sort the array from smallest to largest
np.sort(a)
# Out:
# array([1, 3, 4, 7, 7])

# %%
#Pandas Example

import pandas as pd
#Create data and within two strings (Apples and Oranges) with values for each
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}
#Map the object data
purchases = pd.DataFrame(data)

#Print out purchases in a table view
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
#Matplotlib Example

import matplotlib.pyplot as plt
#Plot the numbers for the graph
plt.plot([1, 3, 1.5, 4, 5, 8])
#Here we can label the X and Y axis with a label we can change
plt.ylabel('Y Values')
plt.xlabel('X Values')
#Print out the plotted graph
plt.show()

# %%
#Seaborn Example

import seaborn as sns
#Sets the theme of the line plot
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# /Users/adamdalton/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
#Pillow Example

from PIL import Image
#Creating a new image that is 400px by 500px and set the Red, Green and Blue
img = Image.new("RGB",(400,500), (255, 0, 0))
#Generates the image and displays the image not on Jupyter but on the machine itself
img.show()

# %% [markdown]
# ![Jupyter%20themes%20example.jpeg](attachment:Jupyter%20themes%20example.jpeg)

# %% [markdown]
# <font color=blue><h3>References</h3>

# %% [markdown]
# <ul>
#     <li>Project Jupyter - https://en.wikipedia.org/wiki/Project_Jupyter</li>
#     <li>JupyterLite - https://jupyterlite.readthedocs.io/en/latest/</li>
#     <li>IPython Cookbook - https://ipython-books.github.io/36-introducing-jupyterlab/</li>
#     <li>10 Reasons to Switch to JupyterLab - https://www.analyticsvidhya.com/blog/2020/06/10-powerful-reasons-jupyterlab-data-science/</li>
#     <li>Most Popular Python Packages in 2021 - https://learnpython.com/blog/most-popular-python-packages/</li>
#     <li>JupyterLite - https://blog.jupyter.org/jupyterlite-jupyter-%EF%B8%8F-webassembly-%EF%B8%8F-python-f6e2e41ab3fa</li>
# </ul>
